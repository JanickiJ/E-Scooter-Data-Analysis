# %% [markdown]
# ## E-Scooter Trips 2020 Chicago

# %%
import warnings

import numpy as np

warnings.filterwarnings("ignore")
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
from pyproj import Geod

# %%
sns.set_style("whitegrid")

# %% [markdown]
# ### 1. Loading dataset

# %%
df = pd.read_csv("data/E-Scooter_Trips_-_2020.csv")
df.head()
# Out:
#                                 Trip ID              Start Time  \
# 0  3eb9a2a3-3266-4559-b1ec-e83a6f7972ab  08/12/2020 05:00:00 AM
# 1  82dd7b8f-8de0-4f25-829b-b32bf47e8419  08/12/2020 05:00:00 AM
# 2  9120cbf3-f749-49b6-b894-0e6e065cd731  08/12/2020 05:00:00 AM
# 3  cf2e4abc-2649-49be-924b-468a1aefc4c8  08/12/2020 05:00:00 AM
# 4  0448afb5-ab64-4090-b528-e3050e7eb0f2  08/12/2020 07:00:00 AM
#
#                  End Time Trip Distance Trip Duration Vendor  \
# 0  08/12/2020 05:00:00 AM         1,153         1,027   spin
# 1  08/12/2020 05:00:00 AM            17            91   spin
# 2  08/12/2020 05:00:00 AM         2,883           724   spin
# 3  08/12/2020 05:00:00 AM             5            21   spin
# 4  08/12/2020 07:00:00 AM         1,179           245   spin
#
#    Start Community Area Number  End Community Area Number  \
# 0                         68.0                       68.0
# 1                         22.0                       21.0
# 2                          3.0                        6.0
# 3                         31.0                       31.0
# 4                          6.0                        6.0
#
#   Start Community Area Name End Community Area Name  Start Centroid Latitude  \
# 0                 ENGLEWOOD               ENGLEWOOD                41.780068
# 1              LOGAN SQUARE                AVONDALE                41.922903
# 2                    UPTOWN               LAKE VIEW                41.965435
# 3           LOWER WEST SIDE         LOWER WEST SIDE                41.848335
# 4                 LAKE VIEW               LAKE VIEW                41.943514
#
#    Start Centroid Longitude           Start Centroid Location  \
# 0                -87.642266  POINT (-87.64226608 41.78006847)
# 1                -87.704301  POINT (-87.70430082 41.92290349)
# 2                -87.655145  POINT (-87.65514456 41.96543532)
# 3                -87.675179  POINT (-87.67517932 41.84833501)
# 4                -87.657498   POINT (-87.65749768 41.9435138)
#
#    End Centroid Latitude  End Centroid Longitude  \
# 0              41.780068              -87.642266
# 1              41.939283              -87.710757
# 2              41.943514              -87.657498
# 3              41.848335              -87.675179
# 4              41.943514              -87.657498
#
#               End Centroid Location
# 0  POINT (-87.64226608 41.78006847)
# 1  POINT (-87.71075685 41.93928256)
# 2   POINT (-87.65749768 41.9435138)
# 3  POINT (-87.67517932 41.84833501)
# 4   POINT (-87.65749768 41.9435138)

# %% [markdown]
# ### 2. Data information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630816 entries, 0 to 630815
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Trip ID                      630816 non-null  object
#  1   Start Time                   630816 non-null  object
#  2   End Time                     630816 non-null  object
#  3   Trip Distance                630816 non-null  object
#  4   Trip Duration                630816 non-null  object
#  5   Vendor                       630816 non-null  object
#  6   Start Community Area Number  629934 non-null  float64
#  7   End Community Area Number    629598 non-null  float64
#  8   Start Community Area Name    629934 non-null  object
#  9   End Community Area Name      629598 non-null  object
#  10  Start Centroid Latitude      629934 non-null  float64
#  11  Start Centroid Longitude     629934 non-null  float64
#  12  Start Centroid Location      629934 non-null  object
#  13  End Centroid Latitude        629598 non-null  float64
#  14  End Centroid Longitude       629598 non-null  float64
#  15  End Centroid Location        629598 non-null  object
# dtypes: float64(6), object(10)
# memory usage: 77.0+ MB

# %% [markdown]
# ### 3. Data preprocessing
# We create following rules for the data:
# 1. Trip needs to last at least 1.5 minutes
# 2. Length of a trip needs to be at least 150 meters

# %% [markdown]
# #### Removing commas from data and converting data type to Int

# %%
df["Trip Duration"] = df["Trip Duration"].str.replace(",", "")
df["Trip Duration"] = df["Trip Duration"].astype("int")
df["Trip Distance"] = df["Trip Distance"].str.replace(",", "")
df["Trip Distance"] = df["Trip Distance"].astype("int")

# %%
original_shape = df.shape

# %% [markdown]
# #### Dropping rows where distance is less than 150 meters or time is less than 90 seconds

# %%
df = df.drop(df[(df['Trip Distance'] < 150) | (df['Trip Duration'] < 90)].index)
new_shape = df.shape

# %%
print(f"Number of rows dropped: {original_shape[0] - new_shape[0]}")
# Out:
# Number of rows dropped: 83596

# %% [markdown]
# ### 4. Number of trips by date, day of week and hour

# %% [markdown]
# #### Converting start time to Datetime data type and creating new column: Start Date

# %%
df.head()['Start Time']
df['Start Date'] = pd.to_datetime(df['Start Time']).dt.date
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %%
ntd = df.groupby("Start Date")["Start Date"].agg(["count"]).reset_index()
ntd.columns = ["Date", "Trips"]
ntd.head()
# Out:
#         Date  Trips
# 0 2020-08-12   2927
# 1 2020-08-13   3697
# 2 2020-08-14   4460
# 3 2020-08-15   5023
# 4 2020-08-16   5296

# %% [markdown]
# #### Average trips per day

# %%
atpd = round(ntd["Trips"].mean())
print(f"Average trips per day: {atpd} trips")
# Out:
# Average trips per day: 4449 trips

# %% [markdown]
# #### 4.1. Number of trips per date

# %%
plt.figure(figsize=(18, 7))
plot = sns.lineplot(x="Date", y="Trips", data=ntd, linewidth=2)
plot.axhline(atpd, linestyle="--", color="purple", label=f"Average = {atpd} trips", linewidth=3)
plt.title("Number of trips by date", size=24)
plt.xlabel("Date", size=24)
plt.ylabel("Number of trips", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# #### 4.2. Number of trips by day of week

# %% [markdown]
# #### Extracting day of week from Start Date column

# %%
df["Day of Week"] = df["Start Date"].dt.day_name()

# %%
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
tdw = df.groupby("Day of Week")["Day of Week"].agg(["count"]).reindex(cats).reset_index()
tdw.columns = ["Day of Week", "Trips"]
tdw
# Out:
#   Day of Week   Trips
# 0      Monday   61128
# 1     Tuesday   60091
# 2   Wednesday   72843
# 3    Thursday   72408
# 4      Friday   88764
# 5    Saturday  105808
# 6      Sunday   86178

# %% [markdown]
# #### Average trips per day of week

# %%
atdw = round(tdw["Trips"].mean())
print(f"Average trips per day of week: {atdw}")
# Out:
# Average trips per day of week: 78174

# %%
plt.figure(figsize=(18, 7))
plot = sns.barplot(x="Day of Week", y="Trips", data=tdw, palette="spring")
for p in plot.patches:
    plot.annotate('{:.0f}'.format(p.get_height()),
                  (p.get_x() + 0.4, p.get_height()),
                  ha='center', va='bottom', color='black', size=15)
plot.axhline(atdw, linestyle="--", color="purple", label=f"Average = {atdw} trips", linewidth=3)
plt.title("Number of trips by day of week", size=24)
plt.xlabel("Day", size=24)
plt.ylabel("Number of trips", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# #### 4.3. Distribution of trips over hours of the day

# %%
df["Hour"] = pd.to_datetime(df["Start Time"]).dt.hour

# %%
thd = df["Hour"].value_counts().to_frame().reset_index()
thd.columns = ["Hour", "Trips"]
thd
# Out:
#     Hour  Trips
# 0     17  58587
# 1     18  58403
# 2     16  52854
# 3     19  49838
# 4     15  47824
# 5     14  41795
# 6     20  39606
# 7     13  37959
# 8     12  34670
# 9     21  30926
# 10    11  28043
# 11    10  20741
# 12     9  15478
# 13     8  12842
# 14     7   8952
# 15     6   5501
# 16     5   2823
# 17    22    251
# 18     3     38
# 19    23     35
# 20     4     21
# 21     0     15
# 22     1     11
# 23     2      7

# %% [markdown]
# #### Average trips per hour

# %%
athd = round(thd["Trips"].mean())
print(f"Average trips per hour: {athd}")
# Out:
# Average trips per hour: 22801

# %%
plt.figure(figsize=(18, 7))
plot = sns.barplot(x="Hour", y="Trips", data=thd, palette="nipy_spectral")
plot.axhline(athd, linestyle="--", color="purple", label=f"Average = {athd} trips", linewidth=3)
plt.title("Number of trips by hour of the day", size=24)
plt.xlabel("Hour", size=24)
plt.ylabel("Number of trips", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# #### 4.4. Number of trips by start area

# %%
ntbsa = df["Start Community Area Name"].value_counts().to_frame().reset_index()
ntbsa.columns = ["Start Community Area Name", "Trips"]
ntbsa
# Out:
#    Start Community Area Name  Trips
# 0                  LAKE VIEW  88850
# 1               LINCOLN PARK  70440
# 2                  WEST TOWN  53413
# 3             NEAR WEST SIDE  28375
# 4               LOGAN SQUARE  25808
# ..                       ...    ...
# 72                      LOOP    147
# 73               FOREST GLEN    143
# 74                  BURNSIDE    123
# 75               EDISON PARK     19
# 76                     OHARE     10
#
# [77 rows x 2 columns]

# %% [markdown]
# #### 4.5. Number of trips by destination area

# %%
ntbea = df["End Community Area Name"].value_counts().to_frame().reset_index()
ntbea.columns = ["End Community Area Name", "Trips"]
ntbea
# Out:
#    End Community Area Name  Trips
# 0                LAKE VIEW  88095
# 1             LINCOLN PARK  68609
# 2                WEST TOWN  53375
# 3           NEAR WEST SIDE  28101
# 4             LOGAN SQUARE  26236
# ..                     ...    ...
# 72                    LOOP    254
# 73             FOREST GLEN    188
# 74                BURNSIDE    173
# 75             EDISON PARK     31
# 76                   OHARE     20
#
# [77 rows x 2 columns]

# %% [markdown]
# ### 5. Average trip speed (km/h)

# %% [markdown]
# #### Creating new column: Average Speed

# %%
df["Average Speed"] = (df["Trip Distance"] / 1000) / (df["Trip Duration"] / 3600)

# %% [markdown]
# #### Average speed of trip

# %%
avs = round(df['Average Speed'].mean(), 2)
print(f"Average speed of trip: {avs} km/h")
# Out:
# Average speed of trip: 14.25 km/h

# %% [markdown]
# #### 5.1 Average speed by date

# %%
atsbd = df.groupby(["Start Date"]).agg({"Average Speed": "mean"}).reset_index()
atsbd.columns = ["Date", "Average Speed"]
atsbd.head()
# Out:
#         Date  Average Speed
# 0 2020-08-12      10.624705
# 1 2020-08-13      11.291829
# 2 2020-08-14      12.718869
# 3 2020-08-15      11.821137
# 4 2020-08-16      11.337374

# %%
plt.figure(figsize=(18, 7))
plot = sns.lineplot(x="Date", y="Average Speed", data=atsbd, linewidth=2)
plot.axhline(avs, linestyle="--", color="purple", label=f"Average speed = {avs} km/h", linewidth=3)
plt.title("Average trip speed by date", size=24)
plt.xlabel("Date", size=24)
plt.ylabel("Average speed", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# #### 5.2 Average speed by day of week

# %%
aspd = df.groupby(["Day of Week"]).agg({"Average Speed": "mean"})
aspd.columns = ["Average Speed"]
aspd = aspd.reset_index()
aspd
# Out:
#   Day of Week  Average Speed
# 0      Friday      14.430455
# 1      Monday      14.207338
# 2    Saturday      13.684364
# 3      Sunday      13.550160
# 4    Thursday      14.826528
# 5     Tuesday      14.735468
# 6   Wednesday      14.708565

# %%
plt.figure(figsize=(18, 7))
plot = sns.barplot(x="Day of Week", y="Average Speed", data=aspd, palette="spring")
plot.axhline(avs, linestyle="--", color="purple", label=f"Average = {avs} km/h", linewidth=3)
plt.title("Average speed by day of week", size=24)
plt.xlabel("Day of week", size=24)
plt.ylabel("Average speed (km/h)", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# #### 5.3 Average speed by start hour

# %%
asph = df.groupby(["Hour"]).agg({"Average Speed": "mean"})
asph.columns = ["Average Speed"]
asph = asph.reset_index()
asph
# Out:
#     Hour  Average Speed
# 0      0      11.500043
# 1      1      12.800828
# 2      2      15.480470
# 3      3      20.016426
# 4      4      19.404634
# 5      5      16.847234
# 6      6      17.849784
# 7      7      17.319672
# 8      8      16.629050
# 9      9      15.736661
# 10    10      15.400405
# 11    11      14.874421
# 12    12      14.542900
# 13    13      14.310593
# 14    14      14.213673
# 15    15      14.020618
# 16    16      14.005575
# 17    17      14.132912
# 18    18      13.883114
# 19    19      13.345882
# 20    20      13.218171
# 21    21      13.441666
# 22    22      14.199006
# 23    23      12.007731

# %%
plt.figure(figsize=(18, 7))
plot = sns.barplot(x="Hour", y="Average Speed", data=asph, palette="nipy_spectral")
plot.axhline(avs, linestyle="--", color="purple", label=f"Average = {avs} km/h", linewidth=3)
plt.title("Average speed by hour of the day", size=24)
plt.xlabel("Hour", size=24)
plt.ylabel("Average speed (km/h)", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# ### 6. Average trip distance

# %%
avd = round(df["Trip Distance"].mean(), 2)
print(f"Average distance per trip: {avd}m")
# Out:
# Average distance per trip: 3347.42m

# %% [markdown]
# #### 6.1. Average trip distance by date

# %%
atdbd = df.groupby(["Start Date"]).agg({"Trip Distance": "mean"}).reset_index()
atdbd.columns = ["Date", "Trip Distance"]
atdbd.head()
# Out:
#         Date  Trip Distance
# 0 2020-08-12    4324.697643
# 1 2020-08-13    4095.524209
# 2 2020-08-14    4255.495067
# 3 2020-08-15    4085.698188
# 4 2020-08-16    4358.191465

# %%
plt.figure(figsize=(18, 7))
plot = sns.lineplot(x="Date", y="Trip Distance", data=atdbd, linewidth=2)
plot.axhline(avd, linestyle="--", color="purple", label=f"Average distance: {avd}m", linewidth=3)
plt.title("Average trip distance by date", size=24)
plt.xlabel("Date", size=24)
plt.ylabel("Average distance", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# #### 6.2. Average trip distance by day of week

# %%
adbd = df.groupby(["Day of Week"]).agg({"Trip Distance": "mean"})
adbd.columns = ["Average Trip Distance"]
adbd = adbd.reset_index()
adbd
# Out:
#   Day of Week  Average Trip Distance
# 0      Friday            3320.206198
# 1      Monday            3345.799028
# 2    Saturday            3378.677123
# 3      Sunday            3516.527617
# 4    Thursday            3274.180049
# 5     Tuesday            3208.915145
# 6   Wednesday            3323.545859

# %%
plt.figure(figsize=(18, 7))
plot = sns.barplot(x="Day of Week", y="Average Trip Distance", data=adbd, palette="spring")
plot.axhline(avd, linestyle="--", color="purple", label=f"Average = {avd}m", linewidth=3)
plt.title("Average trip distance by day of week", size=24)
plt.xlabel("Day of week", size=24)
plt.ylabel("Average trip distance", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# #### 6.3. Average trip distance by hour of the day

# %%
adbh = df.groupby(["Hour"]).agg({"Trip Distance": "mean"})
adbh.columns = ["Average Trip Distance"]
adbh = adbh.reset_index()
adbh
# Out:
#     Hour  Average Trip Distance
# 0      0            2441.333333
# 1      1            2641.272727
# 2      2            6141.857143
# 3      3            9100.921053
# 4      4            5508.857143
# 5      5            3131.513284
# 6      6            2881.840211
# 7      7            2712.753239
# 8      8            2750.184161
# 9      9            2842.364840
# 10    10            2988.430693
# 11    11            3061.949150
# 12    12            3117.799308
# 13    13            3261.132907
# 14    14            3427.323149
# 15    15            3484.832615
# 16    16            3534.112896
# 17    17            3485.992387
# 18    18            3491.445645
# 19    19            3477.187347
# 20    20            3485.241756
# 21    21            3422.400698
# 22    22            4102.840637
# 23    23            3981.914286

# %%
plt.figure(figsize=(18, 7))
plot = sns.barplot(x="Hour", y="Average Trip Distance", data=adbh, palette="nipy_spectral")
plot.axhline(avd, linestyle="--", color="purple", label=f"Average = {avd}m", linewidth=3)
plt.title("Average distance by hour", size=24)
plt.xlabel("Hour", size=24)
plt.ylabel("Average distance", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# ### 7. Trips statistics for first and last 15 days

# %% [markdown]
# #### First 15 days

# %%
ftd = df[(df["Start Date"] >= "2020-08-12") & (df["Start Date"] <= "2020-08-26")]
ftd["Time Period"] = "First 15 Days"

# %% [markdown]
# #### Last 15 days

# %%
ltd = df[(df["Start Date"] >= "2020-11-12") & (df["Start Date"] <= "2020-11-26")]
ltd["Time Period"] = "Last 15 Days"

# %%
fltd = pd.concat([ftd, ltd])

# %% [markdown]
# #### 7.1. Statistics by time period

# %%
fl_15 = fltd.groupby("Time Period").agg({"Time Period": "count",
                                         "Trip Distance": "mean",
                                         "Trip Duration": "mean",
                                         "Average Speed": "mean"})
fl_15.columns = ["Trips", "Trips Distance", "Trips Duration", "Average Speed"]
fl_15 = fl_15.reset_index()
fl_15
# Out:
#      Time Period  Trips  Trips Distance  Trips Duration  Average Speed
# 0  First 15 Days  79187     3938.061083     1448.776201      11.668653
# 1   Last 15 Days  28729     2404.381566      742.904591      14.517974

# %% [markdown]
# #### 7.2. Statistics by day of week and time period

# %%
fltdg = fltd.groupby(["Day of Week", "Time Period"]).agg({"Time Period": "count",
                                                          "Trip Distance": "mean",
                                                          "Trip Duration": "mean",
                                                          "Average Speed": "mean"})
fltdg.columns = ["Trips", "Trips Distance", "Trips Duration", "Average Speed"]
fltdg = fltdg.reset_index()
fltdg
# Out:
#    Day of Week    Time Period  Trips  Trips Distance  Trips Duration  \
# 0       Friday  First 15 Days  11176     4001.340104     1451.206514
# 1       Friday   Last 15 Days   5655     2551.222635      808.118833
# 2       Monday  First 15 Days   9404     4038.129519     1430.084751
# 3       Monday   Last 15 Days   3259     2209.149432      636.962258
# 4     Saturday  First 15 Days  13742     3848.919735     1411.233590
# 5     Saturday   Last 15 Days   4924     2377.294070      756.240861
# 6       Sunday  First 15 Days  11997     4013.857964     1492.836376
# 7       Sunday   Last 15 Days   2923     2303.794389      761.873418
# 8     Thursday  First 15 Days   7745     4001.970562     1563.824403
# 9     Thursday   Last 15 Days   6465     2585.311214      783.619180
# 10     Tuesday  First 15 Days  10717     3954.386302     1428.244565
# 11     Tuesday   Last 15 Days   2561     2122.738383      640.399844
# 12   Wednesday  First 15 Days  14406     3799.053658     1411.633555
# 13   Wednesday   Last 15 Days   2942     2331.250510      693.503059
#
#     Average Speed
# 0       12.123040
# 1       14.450714
# 2       11.946377
# 3       14.931069
# 4       11.522123
# 5       14.090013
# 6       11.421907
# 7       13.996133
# 8       11.174175
# 9       14.771302
# 10      11.906730
# 11      14.689486
# 12      11.568843
# 13      14.718417

# %%
plt.figure(figsize=(18, 7))
sns.barplot(x="Day of Week", y="Trips", hue="Time Period", data=fltdg, palette="hsv")
plt.title("Number of trips by day of week for first and last 15 days", size=24)
plt.xlabel("Days", size=24)
plt.ylabel("Trips", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# #### 7.3. Statistics by hour and time period

# %%
fltdh = fltd.groupby(["Hour", "Time Period"])["Time Period"].agg(["count"]).reset_index()
fltdh.columns = ["Hour", "Time Period", "Trips"]
fltdh
# Out:
#     Hour    Time Period  Trips
# 0      0  First 15 Days      2
# 1      1  First 15 Days      1
# 2      2  First 15 Days      5
# 3      3  First 15 Days      3
# 4      3   Last 15 Days      3
# 5      4  First 15 Days      3
# 6      5  First 15 Days    307
# 7      5   Last 15 Days    255
# 8      6  First 15 Days    534
# 9      6   Last 15 Days    422
# 10     7  First 15 Days    990
# 11     7   Last 15 Days    638
# 12     8  First 15 Days   1475
# 13     8   Last 15 Days    978
# 14     9  First 15 Days   1948
# 15     9   Last 15 Days   1067
# 16    10  First 15 Days   2632
# 17    10   Last 15 Days   1342
# 18    11  First 15 Days   3574
# 19    11   Last 15 Days   1770
# 20    12  First 15 Days   4787
# 21    12   Last 15 Days   2049
# 22    13  First 15 Days   5364
# 23    13   Last 15 Days   2167
# 24    14  First 15 Days   5947
# 25    14   Last 15 Days   2537
# 26    15  First 15 Days   6367
# 27    15   Last 15 Days   2760
# 28    16  First 15 Days   7272
# 29    16   Last 15 Days   2886
# 30    17  First 15 Days   8623
# 31    17   Last 15 Days   2748
# 32    18  First 15 Days   8654
# 33    18   Last 15 Days   2525
# 34    19  First 15 Days   8978
# 35    19   Last 15 Days   1828
# 36    20  First 15 Days   7459
# 37    20   Last 15 Days   1485
# 38    21  First 15 Days   4229
# 39    21   Last 15 Days   1263
# 40    22  First 15 Days     27
# 41    22   Last 15 Days      6
# 42    23  First 15 Days      6

# %%
plt.figure(figsize=(18, 7))
sns.lineplot(x="Hour", y="Trips", hue="Time Period", data=fltdh, palette="spring", linewidth=3)
plt.title("Number of trips by the hour of the day for first and last 15 days", size=24)
plt.xlabel("Hours", size=24)
plt.ylabel("Trips", size=24)
plt.legend(prop={'size': 15})
plt.xticks(size=15)
plt.yticks(size=15)
plt.show()

# %% [markdown]
# ### 8. Starts analysis

# %% [markdown]
# #### 8.1. Starts count on map

# %%
df_location_start = df[['Start Centroid Latitude', 'Start Centroid Longitude']].dropna()
df_location_start, counts_start = np.unique(df_location_start, return_counts=True, axis=0)
df_location_start = np.append(df_location_start, counts_start.reshape((df_location_start.shape[0], -1)), axis=1)

# %%
def draw_starts_number_map(data):
    location_start_map = folium.Map(location=[41.895140898, -87.624255632], zoom_start=13)
    for row in data:
        lat = row[0]
        long = row[1]
        count = row[2]
        radius = count / 3500
        color = "#FF4500"
        popup_text = """Latitude : {}<br>
                    Longitude : {}<br>
                    Starts numer : {}<br>"""
        popup_text = popup_text.format(lat, long, count)
        folium.CircleMarker(location=(lat, long), fill=True, radius=radius, popup=popup_text, color=color).add_to(
            location_start_map)
    return location_start_map


draw_starts_number_map(df_location_start)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c95f7e2811b21526b7792bfbbd77468 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c95f7e2811b21526b7792bfbbd77468&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c95f7e2811b21526b7792bfbbd77468 = L.map(
#                 &quot;map_0c95f7e2811b21526b7792bfbbd77468&quot;,
#                 {
#                     center: [41.895140898, -87.624255632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3430d19b9b6b5cbfd54d7fe1e8faab71 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0c95f7e2811b21526b7792bfbbd77468);
#
#
#             var circle_marker_84ac9b6d350328e749790da5c5f20965 = L.circleMarker(
#                 [41.65789025, -87.6046016],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF4500&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF4500&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.09771428571428571, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c95f7e2811b21526b7792bfbbd77468);
#
#
#         var popup_9c8fc5cfd550d506670241b482ab9b88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a066ee21555cb4f0a72dcf8d4bc3900a = $(`&lt;div id=&quot;html_a066ee21555cb4f0a72dcf8d4bc3900a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude : 41.65789025&lt;br&gt;                     Longitude : -87.6046016&lt;br&gt;                     Starts numer : 342.0&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_9c8fc5cfd550d506670241b482ab9b88.setContent(html_a066ee21555cb4f0a72dcf8d4bc3900a);
#
#
#
#         circle_marker_84ac9b6d350328e749790da5c5f20965.bindPopup(popup_9c8fc5cfd550d506670241b482ab9b88)
#         ;
#
#
#
#
#             var circle_marker_d6a9729597248d5dacbd710cedf5ddc7 = L.circleMarker(
#                 [41.66728092, -87.53544875],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF4500&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF4500&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.11857142857142858, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c95f7e2811b21526b7792bfbbd77468);
#
#
#         var popup_6462d96efd1ad448f404f4910f8b2191 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7f253293fb03803f7214a14bd7f8e671 = $(`&lt;div id=&quot;html_7f253293fb03803f7214a14bd7f8e671&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude : 41.66728092&lt;br&gt;                     Longitude : -87.53544875&lt;br&gt;                     Starts numer : 415.0&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_6462d96efd1ad448f404f4910f8b2191.setContent(html_7f253293fb03803f7214a14bd7f8e671);
#
#
#
#         circle_marker_d6a9729597248d5dacbd710cedf5ddc7.bindPopup(popup_6462d96efd1ad448f404f4910f8b2191)
#         ;
#
#
#
#
#             var circle_marker_f58b21089afe75e6a11d696c22f0ecf6 = L.circleMarker(
#                 [41.67319123, -87.62973311],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF4500&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF4500&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.6457142857142857, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0c95f7e2811b21526b7792bfbbd77468);
#
#
#         var popup_4eb3e5e7d2f32727053a9b2c914bb24a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cdc6f6a9182ac142042a4262392627f7 = $(`&lt;div id=&quot;html_cdc6f6a9182ac142042a4262392627f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Latitude : 41.67319123&lt;br&gt;                     Longitude : -87.62973311&lt;br&gt;                     Starts numer : 2260.0&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_4eb3e5e7d2f32727053a9b2c914bb24a.setContent(html_cdc6f6a9182ac142042a4262

# %% [markdown]
# #### 8.1. Put back location

# %%
areas = df[["Start Community Area Name", 'End Community Area Name']].value_counts().to_frame().reset_index()
areas.columns = ["Start Community Area Name", 'End Community Area Name', "count"]
same_district = areas[(areas["Start Community Area Name"] == areas['End Community Area Name'])].reset_index()
different_district = areas[(areas["Start Community Area Name"] != areas['End Community Area Name'])].reset_index()

fig, ax = plt.subplots()
ax.pie([same_district["count"].sum(), different_district["count"].sum()],
       labels=["Same district", "Different district"], autopct='%1.1f%%')
plt.title("Put back district")
plt.show()

# %% [markdown]
# ### 9. Traffic flow analysis

# %%
areas = df[["Start Community Area Number", 'End Community Area Number']].dropna()
area_count = np.unique(areas).shape[0]
different_district = areas[
    (areas["Start Community Area Number"] != areas['End Community Area Number'])]  #.reset_index()
transfer_arr = np.zeros(shape=(area_count, area_count), dtype=np.int32)

for i, trip in enumerate(different_district.iloc):
    t0 = np.int(trip[0])
    t1 = np.int(trip[1])
    if t0 > t1:
        transfer_arr[t0 - 1, t1 - 1] += 1
    else:
        transfer_arr[t0 - 1, t1 - 1] -= 1

# %%
transfer_arr_norm = transfer_arr / np.linalg.norm(transfer_arr)
print(transfer_arr_norm.shape)
# Out:
# (77, 77)

# %%
area_geo_position = df[['Start Community Area Number', 'Start Centroid Latitude', 'Start Centroid Longitude']].dropna()
area_geo_position = np.unique(area_geo_position, axis=0)

# %%
list_colors = [
    "#00FF00",
    "#12FF00",
    "#24FF00",
    "#35FF00",
    "#47FF00",
    "#58FF00",
    "#6AFF00",
    "#7CFF00",
    "#8DFF00",
    "#9FFF00",
    "#B0FF00",
    "#C2FF00",
    "#D4FF00",
    "#E5FF00",
    "#F7FF00",
    "#FFF600",
    "#FFE400",
    "#FFD300",
    "#FFC100",
    "#FFAF00",
    "#FF9E00",
    "#FF8C00",
    "#FF7B00",
    "#FF6900",
    "#FF5700",
    "#FF4600",
    "#FF3400",
    "#FF2300",
    "#FF1100",
    "#FF0011",
    "#FF0023",
    "#FF0034",
    "#FF0046",
    "#FF0057",
    "#FF0069",
    "#FF007B",
    "#FF008C",
    "#FF009E",
    "#FF00AF",
    "#FF00C1",
    "#FF00D3",
    "#FF00E4",
    "#FF00F6",
    "#F700FF",
    "#E500FF",
    "#D400FF",
]
color_dict = {i: list_colors[i] for i in range(len(list_colors))}

# %%
def draw_flow_map(treshold=1):
    max_count = np.max(transfer_arr)
    print(max_count)
    location_start_map = folium.Map(location=[41.895140898, -87.624255632], zoom_start=12)
    for y in range(transfer_arr.shape[0]):
        for x in range(transfer_arr.shape[1]):
            if x > y and np.abs(transfer_arr[x, y]) > max_count * treshold:
                start_lat = area_geo_position[x, 1]
                start_long = area_geo_position[x, 2]
                end_lat = area_geo_position[y, 1]
                end_long = area_geo_position[y, 2]

                coordinates = [
                    [start_lat, start_long],
                    [end_lat, end_long]
                ]

                color = np.floor(np.log(np.abs(transfer_arr[x, y])) * (30 / np.ceil(np.log(max_count))))
                line = folium.PolyLine(locations=coordinates, weight=color / 2, color=color_dict[color])
                location_start_map.add_child(line)

                geodesic = Geod(ellps='WGS84')
                if transfer_arr[x, y] > 0:
                    rotation = geodesic.inv(start_long, start_lat, end_long, end_lat)[0] - 90
                    arrow_head = folium.RegularPolygonMarker(location=(
                    (end_lat - start_lat) * 0.95 + start_lat, (end_long - start_long) * 0.95 + start_long),
                                                             color=color_dict[color], number_of_sides=3,
                                                             radius=color * 0.75, rotation=rotation)
                else:
                    rotation = geodesic.inv(end_long, end_lat, start_long, start_lat)[0] - 90
                    arrow_head = folium.RegularPolygonMarker(
                        location=((start_lat - end_lat) * 0.95 + end_lat, (start_long - end_long) * 0.95 + end_long),
                        color=color_dict[color], number_of_sides=3, radius=color * 0.75, rotation=rotation)
                location_start_map.add_child(arrow_head)
    return location_start_map

# %%
draw_flow_map(0.01)
# Out:
# 12921
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1387c816686b53104f5ab4c919d95f09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1387c816686b53104f5ab4c919d95f09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1387c816686b53104f5ab4c919d95f09 = L.map(
#                 &quot;map_1387c816686b53104f5ab4c919d95f09&quot;,
#                 {
#                     center: [41.895140898, -87.624255632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_08bf24e2e5df86908dfe5fa695cfd987 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1387c816686b53104f5ab4c919d95f09);
#
#
#             var poly_line_493a08f6f116112033fab1a30103e3b4 = L.polyline(
#                 [[42.00380119, -87.69520764], [42.00888872, -87.67070824]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFE400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFE400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8.0}
#             ).addTo(map_1387c816686b53104f5ab4c919d95f09);
#
#
#             var regular_polygon_marker_7b9804464c5016a2a6791a708fbe0602 = new L.RegularPolygonMarker(
#                 [42.0086343435, -87.67193320999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFE400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFE400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.0, &quot;rotation&quot;: -15.566730833649089, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1387c816686b53104f5ab4c919d95f09);
#
#
#             var poly_line_fa8655e4148fa3b48d7ff1c34391f902 = L.polyline(
#                 [[41.96543532, -87.65514456], [42.00888872, -87.67070824]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFF600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFF600&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 7.5}
#             ).addTo(map_1387c816686b53104f5ab4c919d95f09);
#
#
#             var regular_polygon_marker_8c26ad396a392166b3a2b5890c05c3f8 = new L.RegularPolygonMarker(
#                 [42.00671605, -87.669930056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFF600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFF600&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 11.25, &quot;rotation&quot;: -104.95563262035148, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1387c816686b53104f5ab4c919d95f09);
#
#
#             var poly_line_3a93053448401a2a54fcb7aea10c1ae4 = L.polyline(
#                 [[41.98711448, -87.66434312], [42.00888872, -87.67070824]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF8C00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF8C00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10.5}
#             ).addTo(map_1387c816686b53104f5ab4c919d95f09);
#
#
#             var regular_polygon_marker_70b35218a224538d3c371ab4df895f2c = new L.RegularPolygonMarker(
#                 [42.007800008000004, -87.670389984],
#                 {&quot;bubbl

# %% [markdown]
# #### 9.1. Traffic flow - morning

# %%
def parseDateTime(dateTime: str, fromTime: int, toTime: int):
    result = []
    for dT in dateTime:
        tmp = dT.split()[1:3]
        hour = int(tmp[0].split(':')[0])
        if tmp[1] == 'PM':
            hour += 12
        if fromTime <= hour <= toTime:
            result.append(True)
        else:
            result.append(False)
    return np.array(result)

# %%
areas = df[["Start Time", "Start Community Area Number", "End Community Area Number"]].dropna()
district_filter = np.array(areas["Start Community Area Number"] != areas['End Community Area Number'])
hour_filter = parseDateTime(areas['Start Time'], 6, 10)
sum_filter = []
for i in range(len(district_filter)):
    if district_filter[i] == True and hour_filter[i] == True:
        sum_filter.append(True)
    else:
        sum_filter.append(False)
hour_district = np.array(areas[sum_filter])
transfer_arr = np.zeros(shape=(area_count, area_count), dtype=np.int32)

for i, trip in enumerate(hour_district):
    t0 = np.int(trip[1])
    t1 = np.int(trip[2])
    if t0 > t1:
        transfer_arr[t0 - 1, t1 - 1] += 1
    else:
        transfer_arr[t0 - 1, t1 - 1] -= 1

# %%
draw_flow_map(0.01)
# Out:
# 1307
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c862a718f8bf2ebe033b3b70c40ec26f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c862a718f8bf2ebe033b3b70c40ec26f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c862a718f8bf2ebe033b3b70c40ec26f = L.map(
#                 &quot;map_c862a718f8bf2ebe033b3b70c40ec26f&quot;,
#                 {
#                     center: [41.895140898, -87.624255632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d19f22db4c83bed0b5aafc97d6208ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c862a718f8bf2ebe033b3b70c40ec26f);
#
#
#             var poly_line_e2891333b225ccdc34783a859f5756f4 = L.polyline(
#                 [[42.00380119, -87.69520764], [42.00888872, -87.67070824]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#D4FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#D4FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6.0}
#             ).addTo(map_c862a718f8bf2ebe033b3b70c40ec26f);
#
#
#             var regular_polygon_marker_906463fae0627d9a870502b3b473818c = new L.RegularPolygonMarker(
#                 [42.0086343435, -87.67193320999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#D4FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#D4FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.0, &quot;rotation&quot;: -15.566730833649089, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c862a718f8bf2ebe033b3b70c40ec26f);
#
#
#             var poly_line_2e80135ef805ae5062859e77d9adaaee = L.polyline(
#                 [[41.98711448, -87.66434312], [42.00888872, -87.67070824]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFD300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFD300&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8.5}
#             ).addTo(map_c862a718f8bf2ebe033b3b70c40ec26f);
#
#
#             var regular_polygon_marker_6906c9f385819e32c04bfee325f099c7 = new L.RegularPolygonMarker(
#                 [42.007800008000004, -87.670389984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFD300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFD300&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.75, &quot;rotation&quot;: -102.29890014586161, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c862a718f8bf2ebe033b3b70c40ec26f);
#
#
#             var poly_line_6a0d7db52837d88d850dd225fd6b8f65 = L.polyline(
#                 [[41.97259473, -87.68573583], [42.00380119, -87.69520764]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#C2FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#C2FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5.5}
#             ).addTo(map_c862a718f8bf2ebe033b3b70c40ec26f);
#
#
#             var regular_polygon_marker_6f232ff5546d228f9aac98deb19019a1 = new L.RegularPolygonMarker(
#                 [42.002240867, -87.6947340495],
#                 {&quot;bubbl

# %% [markdown]
# #### 9.2. Traffic flow - afternoon

# %%
draw_flow_map(0.01)
# Out:
# 1307
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_570fc86042d380d5ecfffad6fa377d53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_570fc86042d380d5ecfffad6fa377d53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_570fc86042d380d5ecfffad6fa377d53 = L.map(
#                 &quot;map_570fc86042d380d5ecfffad6fa377d53&quot;,
#                 {
#                     center: [41.895140898, -87.624255632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea107ae12c7991f2c8817ee67a1e09dd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_570fc86042d380d5ecfffad6fa377d53);
#
#
#             var poly_line_690acce8facfa24546f953e0e7f6bf39 = L.polyline(
#                 [[42.00380119, -87.69520764], [42.00888872, -87.67070824]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#D4FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#D4FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 6.0}
#             ).addTo(map_570fc86042d380d5ecfffad6fa377d53);
#
#
#             var regular_polygon_marker_5f037d7494da30ce76ebd57b4a77754f = new L.RegularPolygonMarker(
#                 [42.0086343435, -87.67193320999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#D4FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#D4FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.0, &quot;rotation&quot;: -15.566730833649089, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_570fc86042d380d5ecfffad6fa377d53);
#
#
#             var poly_line_ba27c188ce5c35e52d6f15b6be3f4dd8 = L.polyline(
#                 [[41.98711448, -87.66434312], [42.00888872, -87.67070824]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFD300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFD300&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 8.5}
#             ).addTo(map_570fc86042d380d5ecfffad6fa377d53);
#
#
#             var regular_polygon_marker_b9b078c22743d7d54a9fdd69a54dc34c = new L.RegularPolygonMarker(
#                 [42.007800008000004, -87.670389984],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FFD300&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FFD300&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12.75, &quot;rotation&quot;: -102.29890014586161, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_570fc86042d380d5ecfffad6fa377d53);
#
#
#             var poly_line_cf19f3e3bca7d547da913f55ade9fa80 = L.polyline(
#                 [[41.97259473, -87.68573583], [42.00380119, -87.69520764]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#C2FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#C2FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5.5}
#             ).addTo(map_570fc86042d380d5ecfffad6fa377d53);
#
#
#             var regular_polygon_marker_36307244f2a88df9030b61da83470631 = new L.RegularPolygonMarker(
#                 [42.002240867, -87.6947340495],
#                 {&quot;bubbl

# %% [markdown]
# #### 9.3 Traffic flow per hour

# %%
start_area = df[['Start Community Area Name', 'Hour']].groupby(
    ["Start Community Area Name", "Hour"]).value_counts().reset_index()
start_area.columns = ["Area", "Hour", "Trips"]
start_area["Type"] = ["Start"] * len(start_area)
end_area = df[['End Community Area Name', 'Hour']].groupby(
    ["End Community Area Name", "Hour"]).value_counts().reset_index()
end_area.columns = ["Area", "Hour", "Trips"]
end_area["Type"] = ["End"] * len(end_area)
area_hour_start_end = pd.concat([start_area, end_area])
area_hour_start_end
# Out:
#              Area  Hour  Trips   Type
# 0     ALBANY PARK     5     21  Start
# 1     ALBANY PARK     6     26  Start
# 2     ALBANY PARK     7     30  Start
# 3     ALBANY PARK     8     44  Start
# 4     ALBANY PARK     9     76  Start
# ...           ...   ...    ...    ...
# 1371     WOODLAWN    18    321    End
# 1372     WOODLAWN    19    273    End
# 1373     WOODLAWN    20    225    End
# 1374     WOODLAWN    21    135    End
# 1375     WOODLAWN    22      1    End
#
# [2747 rows x 4 columns]

# %%
def plot_area_hour_start_end(district):
    plt.figure(figsize=(18, 7))
    sns.barplot(x="Hour", y="Trips", hue="Type", data=area_hour_start_end[area_hour_start_end['Area'] == district],
                palette="hsv")
    plt.title(f'Number of starts and ends by hour in {district}', size=24)
    plt.xlabel("Hours", size=24)
    plt.ylabel("Trips", size=24)
    plt.legend(prop={'size': 15})
    plt.xticks(size=15)
    plt.yticks(size=15)
    plt.show()

# %%
districts = ["HERMOSA", "ARCHER HEIGHTS", "HUMBOLDT PARK"]
for district in districts:
    plot_area_hour_start_end(district)

# %% [markdown]
# ### 10.0 Predictions

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from matplotlib.pyplot import figure
from sklearn.neighbors import KNeighborsClassifier, KDTree
from sklearn.ensemble import RandomForestClassifier

# %%
df.columns
# Out:
# Index(['Trip ID', 'Start Time', 'End Time', 'Trip Distance', 'Trip Duration',
#        'Vendor', 'Start Community Area Number', 'End Community Area Number',
#        'Start Community Area Name', 'End Community Area Name',
#        'Start Centroid Latitude', 'Start Centroid Longitude',
#        'Start Centroid Location', 'End Centroid Latitude',
#        'End Centroid Longitude', 'End Centroid Location', 'Start Date',
#        'Day of Week', 'Hour', 'Average Speed'],
#       dtype='object')

# %% [markdown]
# #### Predictions of trip destination point

# %%
features = ['Trip Distance', 'Trip Duration', 'Start Community Area Number', 'Day of Week', 'Hour']

le = preprocessing.LabelEncoder()
tmp = df.dropna()
X = tmp[features]

le.fit(X['Day of Week'])
X['Day of Week'] = le.transform(X['Day of Week'])

Y = pd.DataFrame()
Y['End Community Area Number'] = tmp['End Community Area Number']
le.fit(Y['End Community Area Number'])
Y['End Community Area Number'] = le.transform(Y['End Community Area Number'])

X_train, X_test, Y_train, Y_test = train_test_split(X, Y['End Community Area Number'], test_size=0.20)

# %%
decision_tree = DecisionTreeClassifier()
decision_tree = decision_tree.fit(X_train, Y_train)

predictions = decision_tree.predict(X_test)

print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.64      1530
#            1       0.37      0.40      0.39       504
#            2       0.45      0.45      0.45      4846
#            3       0.40      0.42      0.41      1692
#            4       0.29      0.31      0.30      1808
#            5       0.62      0.62      0.62     17606
#            6       0.53      0.52      0.53     13777
#            7       0.42      0.42      0.42      5171
#            8       0.50      0.50      0.50         6
#            9       0.56      0.40      0.47        68
#           10       0.27      0.26      0.27        95
#           11       0.38      0.42      0.40        33
#           12       0.45      0.39      0.42       244
#           13       0.39      0.38      0.38       528
#           14       0.55      0.56      0.56      1353
#           15       0.35      0.35      0.35       954
#           16       0.43      0.41      0.42       429
#           17       0.47      0.48      0.48       378
#           18       0.58      0.56      0.57      1850
#           19       0.27      0.28      0.27       556
#           20       0.28      0.29      0.29      1078
#           21       0.40      0.41      0.40      5169
#           22       0.38      0.37      0.38      1542
#           23       0.56      0.56      0.56     10564
#           24       0.67      0.66      0.67      1463
#           25       0.39      0.39      0.39       317
#           26       0.38      0.38      0.38       568
#           27       0.60      0.61      0.61      5566
#           28       0.60      0.59      0.60       788
#           29       0.66      0.65      0.66       997
#           30       0.49      0.48      0.49       945
#           31       0.09      0.14      0.11        43
#           32       0.60      0.62      0.61       838
#           33       0.47      0.45      0.46       439
#           34       0.48      0.49      0.48       389
#           35       0.34      0.33      0.33       132
#           36       0.15      0.16      0.15        85
#           37       0.35      0.37      0.36       551
#           38       0.25      0.27      0.26       662
#           39       0.40      0.38      0.39       545
#           40       0.75      0.71      0.73      3067
#           41       0.33      0.31      0.32       670
#           42       0.56      0.55      0.55       789
#           43       0.56      0.55      0.55      1024
#           44       0.37      0.37      0.37       253
#           45       0.55      0.58      0.57       571
#           46       0.21      0.17      0.19        29
#           47       0.51      0.49      0.50       297
#           48       0.61      0.59      0.60      1005
#           49       0.54      0.53      0.54       243
#           50       0.65      0.63      0.64       258
#           51       0.81      0.79      0.80       160
#           52       0.63      0.66      0.64       472
#           53       0.82      0.82      0.82        87
#           54       0.81      0.86      0.84        80
#           55       0.45      0.42      0.43       173
#           56       0.51      0.53      0.52       450
#           57       0.60      0.61      0.60       945
#           58       0.57      0.61      0.59       589
#           59       0.49      0.50      0.49       381
#           60       0.61      0.63      0.62       956
#           61       0.45      0.46      0.45       584
#           62       0.54      0.54      0.54      1060
#           63       0.29      0.31      0.30        77
#           64       0.55      0.49      0.52       692
#           65       0.57      0.58      0.58      1084
#           66       0.54      0.59      0.57       686
#           67       0.52      0.52      0.52       674
#           68       0.40      0.40      0.40       660
#           69       0.54      0.57      0.55       265
#           70       0.59      0.56      0.57       929
#           71       0.46      0.47      0.47       253
#           72       0.48      0.53      0.51       500
#           73       0.90      0.89      0.89       245
#           74       0.42      0.48      0.45       231
#           75       0.00      0.00      0.00         4
#           76       0.45      0.45      0.45      2598
#
#     accuracy                           0.53    109150
#    macro avg       0.48      0.48      0.48    109150
# weighted avg       0.53      0.53      0.53    109150

# %%
knn = KNeighborsClassifier()
knn = knn.fit(X_train, Y_train)

predictions = knn.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.05      0.06      0.06      1530
#            1       0.01      0.02      0.01       504
#            2       0.10      0.13      0.11      4846
#            3       0.03      0.03      0.03      1692
#            4       0.02      0.02      0.02      1808
#            5       0.34      0.57      0.43     17606
#            6       0.24      0.26      0.25     13777
#            7       0.07      0.04      0.05      5171
#            8       0.00      0.00      0.00         6
#            9       0.00      0.00      0.00        68
#           10       0.03      0.01      0.02        95
#           11       0.00      0.00      0.00        33
#           12       0.01      0.00      0.01       244
#           13       0.01      0.00      0.00       528
#           14       0.05      0.04      0.04      1353
#           15       0.02      0.01      0.02       954
#           16       0.02      0.01      0.01       429
#           17       0.01      0.01      0.01       378
#           18       0.05      0.04      0.05      1850
#           19       0.01      0.00      0.00       556
#           20       0.03      0.02      0.02      1078
#           21       0.15      0.17      0.16      5169
#           22       0.04      0.02      0.03      1542
#           23       0.30      0.41      0.35     10564
#           24       0.02      0.01      0.01      1463
#           25       0.01      0.01      0.01       317
#           26       0.02      0.01      0.01       568
#           27       0.20      0.17      0.19      5566
#           28       0.08      0.03      0.05       788
#           29       0.03      0.01      0.01       997
#           30       0.02      0.01      0.01       945
#           31       0.00      0.00      0.00        43
#           32       0.04      0.02      0.03       838
#           33       0.01      0.01      0.01       439
#           34       0.02      0.01      0.01       389
#           35       0.00      0.00      0.00       132
#           36       0.01      0.01      0.01        85
#           37       0.03      0.02      0.02       551
#           38       0.02      0.02      0.02       662
#           39       0.02      0.01      0.02       545
#           40       0.31      0.38      0.34      3067
#           41       0.02      0.01      0.01       670
#           42       0.03      0.02      0.02       789
#           43       0.04      0.03      0.04      1024
#           44       0.01      0.00      0.01       253
#           45       0.02      0.01      0.01       571
#           46       0.00      0.00      0.00        29
#           47       0.00      0.00      0.00       297
#           48       0.05      0.03      0.03      1005
#           49       0.00      0.00      0.00       243
#           50       0.06      0.03      0.04       258
#           51       0.00      0.00      0.00       160
#           52       0.02      0.01      0.01       472
#           53       0.00      0.00      0.00        87
#           54       0.00      0.00      0.00        80
#           55       0.01      0.01      0.01       173
#           56       0.03      0.03      0.03       450
#           57       0.11      0.11      0.11       945
#           58       0.05      0.04      0.04       589
#           59       0.02      0.01      0.01       381
#           60       0.08      0.05      0.06       956
#           61       0.09      0.04      0.05       584
#           62       0.12      0.07      0.09      1060
#           63       0.00      0.00      0.00        77
#           64       0.04      0.01      0.02       692
#           65       0.09      0.05      0.07      1084
#           66       0.07      0.02      0.03       686
#           67       0.05      0.01      0.02       674
#           68       0.07      0.01      0.02       660
#           69       0.00      0.00      0.00       265
#           70       0.08      0.03      0.04       929
#           71       0.02      0.00      0.01       253
#           72       0.07      0.01      0.02       500
#           73       0.11      0.03      0.05       245
#           74       0.19      0.02      0.03       231
#           75       0.00      0.00      0.00         4
#           76       0.42      0.23      0.30      2598
#
#     accuracy                           0.21    109150
#    macro avg       0.06      0.05      0.05    109150
# weighted avg       0.17      0.21      0.19    109150

# %%
random_forest = RandomForestClassifier()
random_forest = random_forest.fit(X_train, Y_train)

predictions = random_forest.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.78      0.75      1530
#            1       0.63      0.50      0.56       504
#            2       0.60      0.53      0.56      4846
#            3       0.59      0.53      0.56      1692
#            4       0.55      0.39      0.46      1808
#            5       0.67      0.75      0.71     17606
#            6       0.62      0.66      0.64     13777
#            7       0.59      0.48      0.53      5171
#            8       0.50      0.17      0.25         6
#            9       0.70      0.28      0.40        68
#           10       0.36      0.19      0.25        95
#           11       0.23      0.09      0.13        33
#           12       0.57      0.45      0.51       244
#           13       0.49      0.42      0.45       528
#           14       0.62      0.71      0.66      1353
#           15       0.53      0.48      0.50       954
#           16       0.56      0.50      0.53       429
#           17       0.67      0.56      0.61       378
#           18       0.66      0.71      0.68      1850
#           19       0.48      0.33      0.39       556
#           20       0.49      0.36      0.41      1078
#           21       0.54      0.52      0.53      5169
#           22       0.59      0.49      0.54      1542
#           23       0.65      0.71      0.68     10564
#           24       0.77      0.78      0.77      1463
#           25       0.65      0.52      0.58       317
#           26       0.61      0.51      0.56       568
#           27       0.72      0.73      0.72      5566
#           28       0.74      0.73      0.74       788
#           29       0.75      0.78      0.77       997
#           30       0.65      0.60      0.63       945
#           31       0.22      0.05      0.08        43
#           32       0.66      0.74      0.70       838
#           33       0.66      0.50      0.57       439
#           34       0.59      0.63      0.61       389
#           35       0.45      0.20      0.27       132
#           36       0.53      0.09      0.16        85
#           37       0.50      0.47      0.49       551
#           38       0.37      0.19      0.25       662
#           39       0.55      0.48      0.51       545
#           40       0.72      0.89      0.80      3067
#           41       0.57      0.38      0.46       670
#           42       0.64      0.67      0.66       789
#           43       0.64      0.71      0.67      1024
#           44       0.57      0.42      0.48       253
#           45       0.62      0.69      0.66       571
#           46       0.00      0.00      0.00        29
#           47       0.63      0.53      0.58       297
#           48       0.67      0.78      0.72      1005
#           49       0.73      0.49      0.58       243
#           50       0.76      0.68      0.72       258
#           51       0.88      0.79      0.84       160
#           52       0.75      0.76      0.76       472
#           53       0.79      0.52      0.62        87
#           54       0.81      0.69      0.74        80
#           55       0.64      0.40      0.49       173
#           56       0.58      0.64      0.60       450
#           57       0.64      0.72      0.68       945
#           58       0.66      0.68      0.67       589
#           59       0.63      0.50      0.56       381
#           60       0.73      0.74      0.74       956
#           61       0.61      0.53      0.57       584
#           62       0.62      0.65      0.64      1060
#           63       0.62      0.10      0.18        77
#           64       0.67      0.60      0.63       692
#           65       0.62      0.71      0.66      1084
#           66       0.68      0.70      0.69       686
#           67       0.65      0.64      0.65       674
#           68       0.55      0.49      0.52       660
#           69       0.71      0.58      0.64       265
#           70       0.65      0.68      0.66       929
#           71       0.54      0.56      0.55       253
#           72       0.60      0.61      0.61       500
#           73       0.87      0.90      0.88       245
#           74       0.58      0.46      0.52       231
#           75       0.00      0.00      0.00         4
#           76       0.60      0.57      0.58      2598
#
#     accuracy                           0.64    109150
#    macro avg       0.60      0.53      0.55    109150
# weighted avg       0.64      0.64      0.64    109150

# %% [markdown]
# #### Predictions of trips duration
#
# W zamyśle dzielimy czas przejazdu na 3 klasy, poniżej 10 min (krótki), powyżej 10 ale poniżej 25 min (średni) oraz przejazdy powyżej 25 min (długie)

# %%
tripDurationClass = np.where(tmp['Trip Duration'] <= 600, 0, np.where(tmp['Trip Duration'] <= 1500, 1, 2))
print(np.unique(tripDurationClass, return_counts=True))
# Out:
# (array([0, 1, 2]), array([254498, 185634, 105615]))

# %%
features = ['Trip Distance', 'Start Community Area Number', 'End Community Area Number', 'Day of Week', 'Hour']

le = preprocessing.LabelEncoder()
tmp = df.dropna()
X = tmp[features]

le.fit(X['Day of Week'])
X['Day of Week'] = le.transform(X['Day of Week'])

Y = pd.DataFrame()
Y['Trip Duration'] = tripDurationClass

X_train, X_test, Y_train, Y_test = train_test_split(X, Y['Trip Duration'], test_size=0.20)

# %%
decision_tree = DecisionTreeClassifier()
decision_tree = decision_tree.fit(X_train, Y_train)

predictions = decision_tree.predict(X_test)

print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69     50735
#            1       0.49      0.49      0.49     37298
#            2       0.49      0.50      0.50     21117
#
#     accuracy                           0.58    109150
#    macro avg       0.56      0.56      0.56    109150
# weighted avg       0.58      0.58      0.58    109150

# %%
knn = KNeighborsClassifier()
knn = knn.fit(X_train, Y_train)

predictions = knn.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.75     50735
#            1       0.56      0.51      0.53     37298
#            2       0.65      0.49      0.56     21117
#
#     accuracy                           0.65    109150
#    macro avg       0.63      0.60      0.61    109150
# weighted avg       0.64      0.65      0.64    109150

# %%
random_forest = RandomForestClassifier()
random_forest = random_forest.fit(X_train, Y_train)

predictions = random_forest.predict(X_test)
print(classification_report(Y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74     50735
#            1       0.56      0.55      0.56     37298
#            2       0.60      0.53      0.57     21117
#
#     accuracy                           0.65    109150
#    macro avg       0.63      0.62      0.62    109150
# weighted avg       0.64      0.65      0.64    109150

# %% [markdown]
# ### 11.0 Transfers Vector Map

# %%
def intersect_ellipse_section(cx, cy, a, b, x1, y1, x2, y2):
    dx = x2 - x1
    dy = y2 - y1
    
    # Define the coefficients for the quadratic equation
    A = dx**2 / a**2 + dy**2 / b**2
    B = 2 * x1 * dx / a**2 + 2 * y1 * dy / b**2
    C = x1**2 / a**2 + y1**2 / b**2 - 1
    
    # Calculate the discriminant
    discriminant = B**2 - 4 * A * C
    
    if discriminant < 0:
        # No intersection
        return None
    elif discriminant == 0:
        # One intersection point
        t = -B / (2 * A)
        if 0 <= t <= 1:
            x = x1 + t * dx
            y = y1 + t * dy
            return [(x, y)]
    else:
        # Two intersection points
        t1 = (-B + np.sqrt(discriminant)) / (2 * A)
        t2 = (-B - np.sqrt(discriminant)) / (2 * A)
        
        intersect_points = []
        if 0 <= t1 <= 1:
            x1 = x1 + t1 * dx
            y1 = y1 + t1 * dy
            intersect_points.append((x1, y1))
        if 0 <= t2 <= 1:
            x2 = x1 + t2 * dx
            y2 = y1 + t2 * dy
            intersect_points.append((x2, y2))
            
        return intersect_points

# %%
def draw_varctor_map(latMin, latMax, lonMin, lonMax, vectorMapData):
    
    location_start_map = folium.Map(location=[(latMax - latMin)/2 +latMin, (lonMax - lonMin) /2 +lonMin], zoom_start=9)
    
    step_lat = (latMax - latMin) / vectorMapData.shape[0]
    step_lon = (lonMax - lonMin) / vectorMapData.shape[1]
    
    max_count = np.max(vectorMapData)
    
    geodesic = Geod(ellps='WGS84')
    for y in range(vectorMapData.shape[0]):
        for x in range(vectorMapData.shape[1]):
            y_cord = latMin + y * step_lat
            x_cord = lonMin + x * step_lon
            
#             lineX = folium.PolyLine(locations=[[latMin, x_cord], [latMax, x_cord]])
#             location_start_map.add_child(lineX)

#             lineY = folium.PolyLine(locations=[[y_cord, lonMin], [y_cord, lonMax]])
#             location_start_map.add_child(lineY)
            
            y_cord += 0.5 * step_lat
            x_cord += 0.5 * step_lon
        
            if(vectorMapData[y, x, 0] > 0):
                color = np.floor(np.log(np.abs(vectorMapData[y, x, 0])) * (40 / np.ceil(np.log(max_count))))
                
#                 tmp_cords = intersect_ellipse_section(0, 0, step_lat/2, step_lon/2, 0, 0, vectorMapData[y, x, 1] - y_cord,vectorMapData[y, x, 2] - x_cord)
#                 if(tmp_cords != None and len(tmp_cords) > 0):
                cordinates = [[y_cord,x_cord], [vectorMapData[y, x, 1] + y_cord, vectorMapData[y, x, 2] + x_cord]]

                line = folium.PolyLine(locations=cordinates, color = color_dict[color], weight=color / 4)
                location_start_map.add_child(line)

                rotation = geodesic.inv(cordinates[0][1], cordinates[0][0], cordinates[1][1], cordinates[1][0])[0] - 90
                arrow_head = folium.RegularPolygonMarker(number_of_sides=3, 
                                                         location=(
                                                             (cordinates[1][0] - cordinates[0][0]) * 0.95 + cordinates[0][0],
                                                             (cordinates[1][1] - cordinates[0][1]) * 0.95 + cordinates[0][1]), 
                                                         rotation=rotation, color = color_dict[color], radius = 7)
                location_start_map.add_child(arrow_head)
            
#     lineX = folium.PolyLine(locations=[[latMin,lonMax], [latMax, lonMax]])
#     location_start_map.add_child(lineX)

#     lineY = folium.PolyLine(locations=[[latMax, lonMin], [latMax, lonMax]])
#     location_start_map.add_child(lineY)
        
    return location_start_map

# %%
def get_line_cells(x1, y1, x2, y2):
    dx = abs(x2 - x1)
    dy = abs(y2 - y1)
    steep = dy > dx

    # If the line is steep, we transpose the coordinates
    if steep:
        x1, y1 = y1, x1
        x2, y2 = y2, x2

    # Ensure we are always iterating from left to right
    if x1 > x2:
        x1, x2 = x2, x1
        y1, y2 = y2, y1

    # Calculate the increments
    dx = x2 - x1
    dy = abs(y2 - y1)
    error = dx / 2
    y_step = 1 if y1 < y2 else -1

    # Start iteration from the starting point
    y = y1
    cells = []

    # Iterate over the x-axis coordinates
    for x in range(x1, x2 + 1):
        cell = (y, x) if steep else (x, y)
        cells.append(cell)
        error -= dy
        if error < 0:
            y += y_step
            error += dx

    return cells

# Data must be in format all float: StartLatitude, EndLatitude, StartLongitude, EndLongitude
def vectorMapDataFormater(sizeY, sizeX, data): 

    minLat = np.min([np.min(data.T[0]), np.min(data.T[1])])
    maxLat = np.max([np.max(data.T[0]), np.max(data.T[1])])
    minLon = np.min([np.min(data.T[2]), np.min(data.T[3])])
    maxLon = np.max([np.max(data.T[2]), np.max(data.T[3])])
    
    paddingLat = (maxLat - minLat) * 0.05
    paddingLon = (maxLon - minLon) * 0.05
    
    minLat = minLat - paddingLat
    maxLat = maxLat + paddingLat
    minLot = minLon - paddingLon
    maxLon = maxLon + paddingLon
    
    stepLat = maxLat - minLat
    stepLon = maxLon - minLon
    
    vectorMapData = np.zeros(shape=(sizeY, sizeX, 3))

    for ride in range(len(data)):
        y1, y2, x1, x2 = data[ride]
        x1, y1, x2, y2 = x1 - minLon, y1 - minLat, x2 - minLon, y2 - minLat
        x1, y1, x2, y2 = x1 / stepLon * sizeX, y1 / stepLat * sizeY, x2 / stepLon * sizeX, y2 / stepLat * sizeY
        x1, y1, x2, y2 = int(np.floor(x1)), int(np.floor(y1)), int(np.floor(x2)), int(np.floor(y2))

        traversed_cells = get_line_cells(x1, y1, x2, y2)

        for (x, y) in traversed_cells:
            if(x != x2 or y != y2):
                vectorMapData[y, x, 0] += 1
                vectorMapData[y, x, 1] += y2 - y
                vectorMapData[y, x, 2] += x2 - x 

    for y in range(sizeY):
        for x in range(sizeX):
            if vectorMapData[y, x, 0] > 0:
                vectorMapData[y, x, 0] = np.max([2, vectorMapData[y, x, 0]])
                vectors = intersect_ellipse_section(0, 0, stepLat/(2*sizeY), stepLon/(2*sizeX), 0, 0, vectorMapData[y, x, 1], vectorMapData[y, x, 2])
                if(vectors != None and len(vectors) > 0):
                    vectorMapData[y, x, 1] = vectors[0][0]
                    vectorMapData[y, x, 2] = vectors[0][1]
                
    return vectorMapData, minLat, maxLat, minLon, maxLon

# %%
features = ['Start Centroid Latitude', 'End Centroid Latitude', 'Start Centroid Longitude', 'End Centroid Longitude']
filtered = df[features].dropna()

# %%
data, minLat, maxLat, minLon, maxLon = vectorMapDataFormater(40, 40, filtered.values) 
draw_varctor_map(minLat, maxLat, minLon, maxLon, data)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b31e8e835f1a7998d55180278f6d78c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b31e8e835f1a7998d55180278f6d78c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b31e8e835f1a7998d55180278f6d78c = L.map(
#                 &quot;map_0b31e8e835f1a7998d55180278f6d78c&quot;,
#                 {
#                     center: [41.833389485, -87.71244468450001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf4a83f56075799540c3fa5df1a63616 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b31e8e835f1a7998d55180278f6d78c);
#
#
#             var poly_line_c89fe30357602a52cbc30569a8b2cb52 = L.polyline(
#                 [[41.6548190133875, -87.6189084561375], [41.65885893603303, -87.62160173790119]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#58FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#58FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1.25}
#             ).addTo(map_0b31e8e835f1a7998d55180278f6d78c);
#
#
#             var regular_polygon_marker_4870d13c3622fd4ec954d50ead74c83c = new L.RegularPolygonMarker(
#                 [41.65865693990075, -87.62146707381301],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#58FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#58FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;rotation&quot;: -116.56262521602358, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b31e8e835f1a7998d55180278f6d78c);
#
#
#             var poly_line_4c6866af9e765b30f510be774a71e7c3 = L.polyline(
#                 [[41.6548190133875, -87.6090625373625], [41.65938172458479, -87.61066700723408]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#B0FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#B0FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_0b31e8e835f1a7998d55180278f6d78c);
#
#
#             var regular_polygon_marker_3f2e0e8bccc84546bda50e3f172e663c = new L.RegularPolygonMarker(
#                 [41.659153589024925, -87.6105867837405],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#B0FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#B0FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 3, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;rotation&quot;: -104.77301555643496, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b31e8e835f1a7998d55180278f6d78c);
#
#
#             var poly_line_9eda3e64a4e2212a4255550794090adc = L.polyline(
#                 [[41.6644714713125, -87.6386002936875], [41.66327889754611, -87.63382999862192]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#58FF00&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#58FF00&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 1.25}
#             ).addTo(map_0b31e8e835f1a7998d55180278f6d78c);
#
#
#             var regular_polygon_marker_dcea1a5cc5b32f3d98672dc305a1a8c2 = new L.RegularPolygonMarker(

# %% [markdown]
# ### 12.0 Korelacja Parsona

# %%
df.columns
# Out:
# Index(['Trip ID', 'Start Time', 'End Time', 'Trip Distance', 'Trip Duration',
#        'Vendor', 'Start Community Area Number', 'End Community Area Number',
#        'Start Community Area Name', 'End Community Area Name',
#        'Start Centroid Latitude', 'Start Centroid Longitude',
#        'Start Centroid Location', 'End Centroid Latitude',
#        'End Centroid Longitude', 'End Centroid Location', 'Start Date',
#        'Day of Week', 'Hour', 'Average Speed'],
#       dtype='object')

# %%
features = ['Trip Distance', 'Trip Duration', 'Vendor', 'Start Community Area Number', 
            'End Community Area Number', 'Start Centroid Latitude', 'Start Centroid Longitude',
            'End Centroid Latitude', 'End Centroid Longitude', 'Start Date',
            'Day of Week', 'Hour', 'Average Speed']

le = preprocessing.LabelEncoder()
X = df[features].dropna()

le.fit(X['Day of Week'])
X['Day of Week'] = le.transform(X['Day of Week'])

le.fit(X['Vendor'])
(X['Vendor']) = le.transform(X['Vendor'])

le.fit(X['Start Date'])
X['Start Date'] = le.transform(X['Start Date'])

# %%
colormap = plt.cm.viridis
plt.figure(figsize=(12,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(X.astype(float).corr(),linewidths=0.1,vmax=1.0,square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <Axes: title={'center': 'Pearson Correlation of Features'}>
